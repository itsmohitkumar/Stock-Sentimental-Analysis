# %% [markdown]
# ### Open a Terminal and run the following commands:
#
# ##### Create a directory for NLTK data
# mkdir -p ~/nltk_data/corpora
#
# ##### Download stopwords manually
# curl https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/packages/corpora/stopwords.zip -o ~/nltk_data/corpora/stopwords.zip
#
# ##### Download wordnet manually
# curl https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/packages/corpora/wordnet.zip -o ~/nltk_data/corpora/wordnet.zip
#
# ##### Unzip the downloaded files
# unzip ~/nltk_data/corpora/stopwords.zip -d ~/nltk_data/corpora/
# unzip ~/nltk_data/corpora/wordnet.zip -d ~/nltk_data/corpora/

# %%
# %pip install pandas numpy nltk scikit-learn
# Out:
# Requirement already satisfied: pandas in /Users/taurangela/Desktop/Github/Stock-Sentimental-Analysis/env/lib/python3.10/site-packages (2.2.2)
# Requirement already satisfied: numpy in /Users/taurangela/Desktop/Github/Stock-Sentimental-Analysis/env/lib/python3.10/site-packages (2.1.0)
# Requirement already satisfied: nltk in /Users/taurangela/Desktop/Github/Stock-Sentimental-Analysis/env/lib/python3.10/site-packages (3.9.1)
# Requirement already satisfied: scikit-learn in /Users/taurangela/Desktop/Github/Stock-Sentimental-Analysis/env/lib/python3.10/site-packages (1.5.1)
# Requirement already satisfied: pytz>=2020.1 in /Users/taurangela/Desktop/Github/Stock-Sentimental-Analysis/env/lib/python3.10/site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/taurangela/Desktop/Github/Stock-Sentimental-Analysis/env/lib/python3.10/site-packages (from pandas) (2024.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/taurangela/Desktop/Github/Stock-Sentimental-Analysis/env/lib/python3.10/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: click in /Users/taurangela/Desktop/Github/Stock-Sentimental-Analysis/env/lib/python3.10/site-packages (from nltk) (8.1.7)
# Requirement already satisfied: tqdm in /Users/taurangela/Desktop/Github/Stock-Sentimental-Analysis/env/lib/python3.10/site-packages (from nltk) (4.66.5)
# Requirement already satisfied: joblib in /Users/taurangela/Desktop/Github/Stock-Sentimental-Analysis/env/lib/python3.10/site-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /Users/taurangela/Desktop/Github/Stock-Sentimental-Analysis/env/lib/python3.10/site-packages (from nltk) (2024.7.24)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/taurangela/Desktop/Github/Stock-Sentimental-Analysis/env/lib/python3.10/site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: scipy>=1.6.0 in /Users/taurangela/Desktop/Github/Stock-Sentimental-Analysis/env/lib/python3.10/site-packages (from scikit-learn) (1.14.1)
# Requirement already satisfied: six>=1.5 in /Users/taurangela/Desktop/Github/Stock-Sentimental-Analysis/env/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# WARNING: You are using pip version 22.0.4; however, version 24.2 is available.
# You should consider upgrading via the '/Users/taurangela/Desktop/Github/Stock-Sentimental-Analysis/env/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ##### Step 1: Importing Libraries

# %%
import pandas as pd
import numpy as np
import nltk
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer, WordNetLemmatizer
import re
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score

# %% [markdown]
# ##### Step 2: Set the NLTK Data Path

# %%
nltk.data.path.append('/Users/taurangela/nltk_data')

# %% [markdown]
# ##### Step 3: Reading the Dataset

# %%
dataset = pd.read_csv('/Users/taurangela/Desktop/Github/Stock-Sentimental-Analysis/data/Sentiment.csv')
dataset = dataset[['text', 'sentiment']]

# %%
dataset
# Out:
#                                                     text sentiment
# 0      RT @NancyLeeGrahn: How did everyone feel about...   Neutral
# 1      RT @ScottWalker: Didn't catch the full #GOPdeb...  Positive
# 2      RT @TJMShow: No mention of Tamir Rice and the ...   Neutral
# 3      RT @RobGeorge: That Carly Fiorina is trending ...  Positive
# 4      RT @DanScavino: #GOPDebate w/ @realDonaldTrump...  Positive
# ...                                                  ...       ...
# 13866  RT @cappy_yarbrough: Love to see men who will ...  Negative
# 13867  RT @georgehenryw: Who thought Huckabee exceede...  Positive
# 13868  RT @Lrihendry: #TedCruz As President, I will a...  Positive
# 13869  RT @JRehling: #GOPDebate Donald Trump says tha...  Negative
# 13870  RT @Lrihendry: #TedCruz headed into the Presid...  Positive
#
# [13871 rows x 2 columns]

# %% [markdown]
# ##### Step 4: Filtering Out Neutral Sentiments

# %%
dataset = dataset[dataset['sentiment'] != 'Neutral']

# %% [markdown]
# ##### Step 5: Splitting the Dataset into Training and Testing Sets

# %%
train, test = train_test_split(dataset, test_size=0.1)

# %% [markdown]
# ##### Step 6: Cleaning and Preprocessing the Text Data

# %%
pattern = "(#\w+)|(RT\s@\w+:)|(http.*)|(@\w+)"
ps = PorterStemmer()
lemmatizer = WordNetLemmatizer()

# %%
def clean_text(data):
    tweets = []
    sentiments = []
    for index, row in data.iterrows():
        sentence = re.sub(pattern, '', row.text)
        words = [e.lower() for e in sentence.split()]
        words = [lemmatizer.lemmatize(word) for word in words if word not in stopwords.words('english')]
        words = ' '.join(words)
        tweets.append(words)
        sentiments.append(row.sentiment)
    return tweets, sentiments

train_tweets, train_sentiments = clean_text(train)

# %% [markdown]
# ##### Step 7: Creating a DataFrame for the Processed Data

# %%
processed_data = pd.DataFrame({'tweets': train_tweets, 'sentiments': train_sentiments})

# %% [markdown]
# ##### Step 8: Encoding Sentiments as Numerical Values

# %%
labelencoder = LabelEncoder()
processed_data['sentiments'] = labelencoder.fit_transform(processed_data['sentiments'])

# %% [markdown]
# ##### Step 9: Converting Words into Vectors using CountVectorizer

# %%
cv = CountVectorizer(ngram_range=(1, 3))
cv.fit(processed_data['tweets'])
X_train = cv.transform(processed_data['tweets'])

# %% [markdown]
# ##### Step 10: Model Building (Sentiment Analysis using Naive Bayes)

# %%
classifier = MultinomialNB()
classifier.fit(X_train.toarray(), processed_data['sentiments'])
# Out:
# MultinomialNB()

# %% [markdown]
# ##### Step 11: Preprocessing the Test Data

# %%
test_tweets, test_sentiments = clean_text(test)
final_test_data = pd.DataFrame({'tweets': test_tweets, 'sentiments': test_sentiments})
X_test = cv.transform(final_test_data['tweets'])

# %% [markdown]
# ##### Step 12: Predicting Sentiments on the Test Data

# %%
y_pred = classifier.predict(X_test.toarray())

# %% [markdown]
# ##### Step 13: Evaluating the Model

# %%
final_test_data['sentiments'] = labelencoder.fit_transform(final_test_data['sentiments'])
accuracy = accuracy_score(y_pred, final_test_data['sentiments'])
print(f"Accuracy: {accuracy}")
# Out:
# Accuracy: 0.8378378378378378

# %% [markdown]
# ##### Step 14: Displaying the Final Test Data with Predictions

# %%
final_test_data
# Out:
#                                                  tweets  sentiments
# 0                                    godfather american           0
# 1     wish hilary carly fiorina passion spark! take ...           1
# 2                                       call gentleman.           1
# 3     fox made play womens victim professional. ragi...           0
# 4                     wait said use say "when used it?"           0
# ...                                                 ...         ...
# 1068  huckabee like science threatens god, like circ...           0
# 1069                 "when actually become republican?"           0
# 1070  candidate received word god?! presidential hop...           0
# 1071  look substance need discussion. successful eve...           1
# 1072                ben carson, solidifying black vote.           1
#
# [1073 rows x 2 columns]

# %% [markdown]
# #####
